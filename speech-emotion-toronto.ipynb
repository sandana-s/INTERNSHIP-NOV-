# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths =[]
labels=[]

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label= filename.split('_')[-1]
        label=label.split('.')[0].lower()
        labels.append(label)
        
        
print('Dataset is loaded')
# Out:
# Dataset is loaded

# %%
paths[:5]
# Out:
# ['/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_home_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_youth_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_near_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_pick_fear.wav']

# %%
labels[:5]
# Out:
# ['fear', 'fear', 'fear', 'fear', 'fear']

# %%
df=pd.DataFrame()
df['speech']=paths
df['label']= labels
df.head()
# Out:
#                                               speech label
# 0  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 1  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 2  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 3  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 4  /kaggle/input/toronto-emotional-speech-set-tes...  fear

# %%
df['label'].value_counts()
# Out:
# label
# fear       800
# angry      800
# disgust    800
# neutral    800
# sad        800
# ps         800
# happy      800
# Name: count, dtype: int64

# %%
def waveplot(data,sr,emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion,size=20)
    librosa.display.waveshow(data,sr=sr)
    plt.show()
def spectrogram(data,sr,emotion):
    x=librosa.stft(data)
    xdb=librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(10,4))
    plt.title(emotion,size=20)
    librosa.display.specshow(xdb,sr=sr,x_axis='time',y_axis='hz')
    plt.colorbar()

# %%
emotion='fear'
path=np.array(df['speech'][df['label']==emotion])[0]
data,sampling_rate=librosa.load(path)
waveplot(data,sampling_rate,emotion)
spectrogram(data,sampling_rate,emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='angry'
path=np.array(df['speech'][df['label']==emotion])[0]
data,sampling_rate=librosa.load(path)
waveplot(data,sampling_rate,emotion)
spectrogram(data,sampling_rate,emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y,sr=librosa.load(filename,duration=3,offset=0.5)
    mfcc=np.mean(librosa.feature.mfcc(y=y,sr=sr,n_mfcc=40).T,axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-285.73727  ,   85.78295  ,   -2.1689117,   22.125532 ,
#         -14.757396 ,   11.051347 ,   12.412449 ,   -3.000262 ,
#           1.0844985,   11.078271 ,  -17.41966  ,   -8.093213 ,
#           6.5879736,   -4.2209525,   -9.15508  ,    3.5214796,
#         -13.186381 ,   14.078853 ,   19.66973  ,   22.725618 ,
#          32.57464  ,   16.325033 ,   -3.8427284,    0.8962967,
#         -11.239264 ,    6.653461 ,   -2.5883694,   -7.7140164,
#         -10.941657 ,   -2.4007552,   -5.2812862,    4.271157 ,
#         -11.202216 ,   -9.024621 ,   -3.666985 ,    4.8697433,
#          -1.6027987,    2.5600514,   11.454374 ,   11.233449 ],
#       dtype=float32)

# %%
x_mfcc=df['speech'].apply(lambda x:extract_mfcc(x))
x_mfcc
# Out:
# 0       [-285.73727, 85.78295, -2.1689117, 22.125532, ...
# 1       [-348.34332, 35.193233, -3.8413284, 14.658875,...
# 2       [-340.11435, 53.796444, -14.267782, 20.884031,...
# 3       [-306.63422, 21.259708, -4.4110823, 6.4871554,...
# 4       [-344.7548, 46.329193, -24.171413, 19.392921, ...
#                               ...
# 5595    [-374.3952, 60.864998, 0.02505877, 8.431058, -...
# 5596    [-313.96478, 39.847843, -5.6493053, -3.8675754...
# 5597    [-357.54886, 77.88605, -15.224756, 2.194633, -...
# 5598    [-353.1474, 101.68391, -14.175897, -12.037376,...
# 5599    [-389.4595, 54.042767, 1.3469982, -1.4258989, ...
# Name: speech, Length: 5600, dtype: object

# %%
x=[x for x in x_mfcc]
x=np.array(x)
x.shape
# Out:
# (5600, 40)

# %%
x=np.expand_dims(x,-1)
x.shape
# Out:
# (5600, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc=OneHotEncoder()
y=enc.fit_transform(df[['label']])

# %%
y=y.toarray()

# %%
y.shape
# Out:
# (5600, 7)

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout

model=Sequential([
    LSTM(123,return_sequences=False,input_shape=(40,1)),
    Dense(64,activation='relu'),
    Dropout(0.2),
    Dense(32,activation='relu'),
    Dropout(0.2),
    Dense(7,activation='softmax')
])

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 123)            │        61,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         7,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 71,747 (280.26 KB)
#  Trainable params: 71,747 (280.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(x,y,validation_split=0.2,epochs=100,batch_size=512,shuffle=True)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.2511 - loss: 1.8898 - val_accuracy: 0.1884 - val_loss: 1.9295
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.5058 - loss: 1.5689 - val_accuracy: 0.2313 - val_loss: 1.9024
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.6282 - loss: 1.1206 - val_accuracy: 0.2170 - val_loss: 1.6413
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.7142 - loss: 0.8110 - val_accuracy: 0.5589 - val_loss: 1.0390
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.7773 - loss: 0.6286 - val_accuracy: 0.7616 - val_loss: 0.6710
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.8402 - loss: 0.4625 - val_accuracy: 0.8286 - val_loss: 0.4626
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.8726 - loss: 0.3631 - val_accuracy: 0.8705 - val_loss: 0.3475
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.9005 - loss: 0.3028 - val_accuracy: 0.8679 - val_loss: 0.3763
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9158 - loss: 0.2748 - val_accuracy: 0.8616 - val_loss: 0.3636
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9248 - loss: 0.2380 - val_accuracy: 0.9348 - val_loss: 0.2205
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.9503 - loss: 0.1759 - val_accuracy: 0.9482 - val_loss: 0.1736
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.9506 - loss: 0.1720 - val_accuracy: 0.9259 - val_loss: 0.2268
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9598 - loss: 0.1399 - val_accuracy: 0.9464 - val_loss: 0.1617
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9608 - loss: 0.1241 - val_accuracy: 0.9438 - val_loss: 0.1566
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9656 - loss: 0.1162 - val_accuracy: 0.9625 - val_loss: 0.1189
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.9687 - loss: 0.1106 - val_accuracy: 0.9571 - val_loss: 0.1287
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9740 - loss: 0.0926 - val_accuracy: 0.9670 - val_loss: 0.0984
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9833 - loss: 0.0621 - val_accuracy: 0.9804 - val_loss: 0.0708
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.9764 - loss: 0.0751 - val_accuracy: 0.9768 - val_loss: 0.0792
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9782 - loss: 0.0735 - val_accuracy: 0.9571 - val_loss: 0.1521
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.9801 - loss: 0.0723 - val_accuracy: 0.9598 - val_loss: 0.1116
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9799 - loss: 0.0674 - val_accuracy: 0.9732 - val_loss: 0.0853
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.9741 - loss: 0.0775 - val_accuracy: 0.9812 - val_loss: 0.0631
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9846 - loss: 0.0554 - val_accuracy: 0.9839 - val_loss: 0.0589
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9809 - loss: 0.0592 - val_accuracy: 0.9661 - val_loss: 0.1001
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9714 - loss: 0.0956 - val_accuracy: 0.9804 - val_loss: 0.0577
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9704 - loss: 0.0982 - val_accuracy: 0.9830 - val_loss: 0.0613
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9814 - loss: 0.0729 - val_accuracy: 0.9741 - val_loss: 0.0804
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9826 - loss: 0.0572 - val_accuracy: 0.9857 - val_loss: 0.0403
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9828 - loss: 0.0602 - val_accuracy: 0.9786 - val_loss: 0.0689
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9886 - loss: 0.0461 - val_accuracy: 0.9875 - val_loss: 0.0369
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9892 - loss: 0.0334 - val_accuracy: 0.9812 - val_loss: 0.0516
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9913 - loss: 0.0328 - val_accuracy: 0.9795 - val_loss: 0.0661
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9903 - loss: 0.0335 - val_accuracy: 0.9902 - val_loss: 0.0314
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9894 - loss: 0.0390 - val_accuracy: 0.9839 - val_loss: 0.0492
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9878 - loss: 0.0382 - val_accuracy: 0.9920 - val_loss: 0.0265
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9899 - loss: 0.0336 - val_accuracy: 0.9875 - val_loss: 0.0386
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.9931 - loss: 0.0267 - val_accuracy: 0.9929 - val_loss: 0.0275
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9936 - loss: 0.0264 - val_accuracy: 0.9893 - val_loss: 0.0339
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.9914 - loss: 0.0286 - val_accuracy: 0.9830 - val_loss: 0.0525
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9919 - loss: 0.0323 - val_accuracy: 0.9839 - val_loss: 0.0435
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.9900 - loss: 0.0383 - val_accuracy: 0.9857 - val_loss: 0.0391
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9913 - loss: 0.0289 - val_accuracy: 0.9902 - val_loss: 0.0271
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9925 - loss: 0.0273 - val_accuracy: 0.9929 - val_loss: 0.0232
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 228ms/step - accuracy: 0.9908 - loss: 0.0332 - val_accuracy: 0.9946 - val_loss: 0.0213
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9909 - loss: 0.0267 - val_accuracy: 0.9848 - val_loss: 0.0348
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9931 - loss: 0.0235 - val_accuracy: 0.9830 - val_loss: 0.0456
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9937 - loss: 0.0220 - val_accuracy: 0.9929 - val_loss: 0.0185
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9947 - loss: 0.0156 - val_accuracy: 0.9946 - val_loss: 0.0199
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9958 - loss: 0.0159 - val_accuracy: 0.9857 - val_loss: 0.0373
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9936 - loss: 0.0191 - val_accuracy: 0.9929 - val_loss: 0.0206
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.9928 - loss: 0.0178 - val_accuracy: 0.9839 - val_loss: 0.0484
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9960 - loss: 0.0165 - val_accuracy: 0.9920 - val_loss: 0.0200
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9944 - loss: 0.0187 - val_accuracy: 0.9911 - val_loss: 0.0226
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.9945 - loss: 0.0181 - val_accuracy: 0.9884 - val_loss: 0.0281
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9949 - loss: 0.0179 - val_accuracy: 0.9821 - val_loss: 0.0459
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9934 - loss: 0.0229 - val_accuracy: 0.9911 - val_loss: 0.0225
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9948 - loss: 0.0205 - val_accuracy: 0.9955 - val_loss: 0.0155
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9964 - loss: 0.0143 - val_accuracy: 0.9920 - val_loss: 0.0212
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9920 - loss: 0.0224 - val_accuracy: 0.9830 - val_loss: 0.0584
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.9899 - loss: 0.0377 - val_accuracy: 0.9929 - val_loss: 0.0216
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.9929 - loss: 0.0253 - val_accuracy: 0.9812 - val_loss: 0.0565
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9871 - loss: 0.0361 - val_accuracy: 0.9661 - val_loss: 0.1051
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.9892 - loss: 0.0413 - val_accuracy: 0.9857 - val_loss: 0.0353
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9900 - loss: 0.0267 - val_accuracy: 0.9911 - val_loss: 0.0259
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9908 - loss: 0.0393 - val_accuracy: 0.9920 - val_loss: 0.0370
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9892 - loss: 0.0310 - val_accuracy: 0.9955 - val_loss: 0.0157
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9930 - loss: 0.0225 - val_accuracy: 0.9857 - val_loss: 0.0304
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9968 - loss: 0.0128 - val_accuracy: 0.9982 - val_loss: 0.0088
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9970 - loss: 0.0130 - val_accuracy: 0.9929 - val_loss: 0.0147
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9979 - loss: 0.0091 - val_accuracy: 0.9982 - val_loss: 0.0082
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9972 - loss: 0.0123 - val_accuracy: 0.9973 - val_loss: 0.0085
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9974 - loss: 0.0083 - val_accuracy: 0.9982 - val_loss: 0.0063
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9974 - loss: 0.0088 - val_accuracy: 0.9991 - val_loss: 0.0056
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9980 - loss: 0.0074 - val_accuracy: 0.9973 - val_loss: 0.0107
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9985 - loss: 0.0094 - val_accuracy: 0.9973 - val_loss: 0.0077
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9987 - loss: 0.0062 - val_accuracy: 0.9946 - val_loss: 0.0127
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9973 - val_loss: 0.0078
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9993 - loss: 0.0058 - val_accuracy: 0.9991 - val_loss: 0.0043
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9982 - val_loss: 0.0050
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9937 - val_loss: 0.0170
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9958 - loss: 0.0167 - val_accuracy: 0.9955 - val_loss: 0.0157
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.9949 - loss: 0.0151 - val_accuracy: 0.9964 - val_loss: 0.0085
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9962 - loss: 0.0113 - val_accuracy: 0.9955 - val_loss: 0.0157
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.9962 - loss: 0.0102 - val_accuracy: 0.9982 - val_loss: 0.0084
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9964 - loss: 0.0113 - val_accuracy: 0.9991 - val_loss: 0.0053
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9989 - loss: 0.0061 - val_accuracy: 0.9991 - val_loss: 0.0039
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9991 - val_loss: 0.0031
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9991 - loss: 0.0056 - val_accuracy: 0.9982 - val_loss: 0.0043
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9995 - loss: 0.0045 - val_accuracy: 0.9991 - val_loss: 0.0033
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9981 - loss: 0.0047 - val_accuracy: 0.9991 - val_loss: 0.0031
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9991 - val_loss: 0.0028
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9992 - loss: 0.0045 - val_accuracy: 0.9991 - val_loss: 0.0030
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9991 - loss: 0.0040 - val_accuracy: 0.9991 - val_loss: 0.0023
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9982 - val_loss: 0.0039
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.9989 - loss: 0.0031 - val_accuracy: 0.9991 - val_loss: 0.0019
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9998 - loss: 0.0023 - val_accuracy: 0.9991 - val_loss: 0.0022
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 221ms/step - accuracy: 0.9986 - loss: 0.0034 - val_accuracy: 0.9991 - val_loss: 0.0017
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9994 - loss: 0.0036 - val_accuracy: 0.9964 - val_loss: 0.0067
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9970 - loss: 0.0202 - val_accuracy: 0.9911 - val_loss: 0.0213

# %%
epoch=range(1,101)
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

plt.plot(epoch,acc,label='train_accuracy')
plt.plot(epoch,val_acc,label='val_accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()
